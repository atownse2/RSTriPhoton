# %%
import sys
import importlib

sys.path.append("../")

from analysis.utils import sample_info as si

# %%
importlib.reload(si)

fileset = si.get_filesets('data')

# %%
fileset
# Out:
# {'DoubleEG_Run2017B': {'files': ['/store/data/Run2017B/DoubleEG/NANOAOD/UL2017_MiniAODv2_NanoAODv9-v1/70000/4BC53825-C4CC-264D-B251-87375F80A49E.root',
#    '/store/data/Run2017B/DoubleEG/NANOAOD/UL2017_MiniAODv2_NanoAODv9-v1/70000/AA934002-6CA2-C141-B724-728F9542256D.root',
#    '/store/data/Run2017B/DoubleEG/NANOAOD/UL2017_MiniAODv2_NanoAODv9-v1/70000/BB7E632C-9672-4E4C-867D-590E69A1269C.root',
#    '/store/data/Run2017B/DoubleEG/NANOAOD/UL2017_MiniAODv2_NanoAODv9-v1/70000/83110FE1-A540-3A4B-A81C-2454A017C471.root',
#    '/store/data/Run2017B/DoubleEG/NANOAOD/UL2017_MiniAODv2_NanoAODv9-v1/70000/2A428A4E-12E5-3449-8E0F-9DA6C64A7449.root',
#    '/store/data/Run2017B/DoubleEG/NANOAOD/UL2017_MiniAODv2_NanoAODv9-v1/70000/8939430E-0EF1-D045-BAE9-FB60D6FF7BAF.root',
#    '/store/data/Run2017B/DoubleEG/NANOAOD/UL2017_MiniAODv2_NanoAODv9-v1/70000/3A77A223-60EF-024E-89AF-A03783DC4F63.root',
# ...
